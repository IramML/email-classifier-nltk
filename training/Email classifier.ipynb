# %% [markdown]
# # Add libraries
# ---

# %%
import os
import nltk
import random
from nltk import word_tokenize
from nltk.collocations import *
import pandas as pd

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # Load corpus datasets
# ---

# %%
# !git clone https://github.com/pachocamacho1990/datasets
! unzip datasets/email/plaintext/corpus1.zip
! unzip datasets/email/plaintext/corpus2.zip
! unzip datasets/email/plaintext/corpus3.zip

# %%
# Get Text and labels from folders with plain text files
def get_text_labels_from_folders(folderBase, folderLabels):
  data = []
  labels = []

  for folderLabel in folderLabels:
    for file in os.listdir('{}/{}'.format(folderBase, folderLabel)):
      with open('{}/{}/{}'.format(folderBase, folderLabel, file), encoding='latin-1') as f:
        data.append(f.read())
        labels.append(folderLabel)

  return data, labels

# %%
def set_label_num(label_str):
  if label_str == "spam":
      return 1
  else:
      return 0

# %%
dataCorpus1, labelsCorpus1 = get_text_labels_from_folders('corpus1', ["spam", "ham"])
dataCorpus2, labelsCorpus2 = get_text_labels_from_folders('corpus2', ["spam", "ham"])
dataCorpus3, labelsCorpus3 = get_text_labels_from_folders('corpus3', ["spam", "ham"])

# %%
data = dataCorpus1 + dataCorpus2 + dataCorpus3
labels = labelsCorpus1 + labelsCorpus2 + labelsCorpus3

# %%
len(data)
# Out:
# 16347

# %%
dataframe = pd.DataFrame({'text': data, 'labels': labels})

# %%
dataframe['tokens'] = dataframe['text'].apply(lambda x: word_tokenize(x))

# %%
dataframe['labels_num'] = dataframe['labels'].apply(lambda x: set_label_num(x))

# %% [markdown]
# # Collocations
# ---

# %%
spamCorpus1, _ = get_text_labels_from_folders('corpus1', ["spam"])
spamCorpus2, _ = get_text_labels_from_folders('corpus2', ["spam"])
spamCorpus3, _ = get_text_labels_from_folders('corpus3', ["spam"])

# %%
spamCorpuses = spamCorpus1 + spamCorpus2 + spamCorpus3

# %%
threshold = 3
bigram_measure = nltk.collocations.BigramAssocMeasures()
filtered_words = []
for text in spamCorpuses:
  filtered_words += [word for word in word_tokenize(text) if len(word) > threshold]

# %%
filtered_words

# %%
finder = BigramCollocationFinder.from_words(filtered_words)
finder.apply_freq_filter(120)
email_spam_collocations = finder.nbest(bigram_measure.pmi, 40)

# %%
email_spam_collocations

# %% [markdown]
# # Get document attributes
# ---

# %%
dataframe.head()
# Out:
#                                                 text  ... labels_num
# 0  Subject: dating service for nauuughty minded p...  ...          1
# 1  Subject: aylesbgry sgclude oisv msjgnkrlf\nhel...  ...          1
# 2  Subject: reverse aging ! new technology !\nrev...  ...          1
# 3  Subject: reduce monthly - payments\nyour appli...  ...          1
# 4  Subject: viewsonic airpanel vl 50 15 - inch sm...  ...          1
#
# [5 rows x 4 columns]

# %%
def document_attributes(document):
  document_words = set(document)
  atrib = {}

  last_word = ""
  for word in document_words:
    atrib['contains({})'.format(word)] = (word in document_words)

    has_spam_word = False
    has_spam_collocation = False

    for bigram_position_0, bigram_position_1 in email_spam_collocations:
      if word == bigram_position_0 or word == bigram_position_1:
        has_spam_word = True
        if has_spam_collocation and has_spam_word:
          break

      if last_word != "" and ( last_word == bigram_position_0 and word == bigram_position_0 ):
        has_spam_collocation = True
        if has_spam_collocation and has_spam_word:
          break
    
    atrib['has_spam_word({})'.format(word)] = True if has_spam_word else False
    atrib['has_spam_collocation({})'.format(word)] = True if has_spam_collocation else False

    if (len(word) > 3):
      lastWord = word
    
  return atrib

# %%
dataframe.size
# Out:
# 65388

# %%
print(dataframe['tokens'].values[0])
print()
print("===="*100)
print()
print(document_attributes(dataframe['tokens'].values[0]))
# Out:
# ['Subject', ':', 'dating', 'service', 'for', 'nauuughty', 'minded', 'people', 'hi', '.', 'real', 'women', 'in', 'a', 'city', 'by', 'city', 'database', 'of', 'chics', 'that', 'like', 'to', 'cheaaatt', '.', 'some', 'like', 'submissive', ',', 'some', 'like', 'kinky', ',', 'some', 'like', 'to', 'be', 'forced', '.', 'check', 'them', 'out', '.', 'it', "'", 's', 'absolutely', 'nnno', '0', 'cost', 'to', 'try', 'it', 'and', 'to', 'peruse', 'the', 'database', 'for', 'free', '.', 'http', ':', '/', '/', 'dateeemywifxxp', '.', 'com', 'to', 'get', 'the', 'hell', 'out', 'of', 'this', 'stuff', 'go', 'to', 'here', '.', '.', '.', '.', 'http', ':', '/', '/', 'safebuyinghouse', '.', 'com', '/', 'tx']
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================
#
# {'contains(forced)': True, 'has_spam_word(forced)': False, 'has_spam_collocation(forced)': False, 'contains(be)': True, 'has_spam_word(be)': False, 'has_spam_collocation(be)': False, 'contains(real)': True, 'has_spam_word(real)': False, 'has_spam_collocation(real)': False, 'contains(here)': True, 'has_spam_word(here)': False, 'has_spam_collocation(here)': False, 'contains(to)': True, 'has_spam_word(to)': False, 'has_spam_collocation(to)': False, 'contains(them)': True, 'has_spam_word(them)': False, 'has_spam_collocation(them)': False, "contains(')": True, "has_spam_word(')": False, "has_spam_collocation(')": False, 'contains(kinky)': True, 'has_spam_word(kinky)': False, 'has_spam_collocation(kinky)': False, 'contains(out)': True, 'has_spam_word(out)': False, 'has_spam_collocation(out)': False, 'contains(chics)': True, 'has_spam_word(chics)': False, 'has_spam_collocation(chics)': False, 'contains(the)': True, 'has_spam_word(the)': False, 'has_spam_collocation(the)': False, 'contains(like)': True, 'has_spam_word(like)': False, 'has_spam_collocation(like)': False, 'contains(,)': True, 'has_spam_word(,)': False, 'has_spam_collocation(,)': False, 'contains(tx)': True, 'has_spam_word(tx)': False, 'has_spam_collocation(tx)': False, 'contains(and)': True, 'has_spam_word(and)': False, 'has_spam_collocation(and)': False, 'contains(for)': True, 'has_spam_word(for)': False, 'has_spam_collocation(for)': False, 'contains(stuff)': True, 'has_spam_word(stuff)': False, 'has_spam_collocation(stuff)': False, 'contains(go)': True, 'has_spam_word(go)': False, 'has_spam_collocation(go)': False, 'contains(absolutely)': True, 'has_spam_word(absolutely)': False, 'has_spam_collocation(absolutely)': False, 'contains(hell)': True, 'has_spam_word(hell)': False, 'has_spam_collocation(hell)': False, 'contains(hi)': True, 'has_spam_word(hi)': False, 'has_spam_collocation(hi)': False, 'contains(http)': True, 'has_spam_word(http)': False, 'has_spam_collocation(http)': False, 'contains(/)': True, 'has_spam_word(/)': False, 'has_spam_collocation(/)': False, 'contains(safebuyinghouse)': True, 'has_spam_word(safebuyinghouse)': False, 'has_spam_collocation(safebuyinghouse)': False, 'contains(cheaaatt)': True, 'has_spam_word(cheaaatt)': False, 'has_spam_collocation(cheaaatt)': False, 'contains(women)': True, 'has_spam_word(women)': False, 'has_spam_collocation(women)': False, 'contains(nnno)': True, 'has_spam_word(nnno)': False, 'has_spam_collocation(nnno)': False, 'contains(minded)': True, 'has_spam_word(minded)': False, 'has_spam_collocation(minded)': False, 'contains(submissive)': True, 'has_spam_word(submissive)': False, 'has_spam_collocation(submissive)': False, 'contains(Subject)': True, 'has_spam_word(Subject)': False, 'has_spam_collocation(Subject)': False, 'contains(.)': True, 'has_spam_word(.)': False, 'has_spam_collocation(.)': False, 'contains(a)': True, 'has_spam_word(a)': False, 'has_spam_collocation(a)': False, 'contains(dateeemywifxxp)': True, 'has_spam_word(dateeemywifxxp)': False, 'has_spam_collocation(dateeemywifxxp)': False, 'contains(cost)': True, 'has_spam_word(cost)': False, 'has_spam_collocation(cost)': False, 'contains(get)': True, 'has_spam_word(get)': False, 'has_spam_collocation(get)': False, 'contains(this)': True, 'has_spam_word(this)': False, 'has_spam_collocation(this)': False, 'contains(database)': True, 'has_spam_word(database)': False, 'has_spam_collocation(database)': False, 'contains(people)': True, 'has_spam_word(people)': False, 'has_spam_collocation(people)': False, 'contains(peruse)': True, 'has_spam_word(peruse)': False, 'has_spam_collocation(peruse)': False, 'contains(service)': True, 'has_spam_word(service)': False, 'has_spam_collocation(service)': False, 'contains(in)': True, 'has_spam_word(in)': False, 'has_spam_collocation(in)': False, 'contains(try)': True, 'has_spam_word(try)': False, 'has_spam_collocation(try)': False, 'contains(0)': True, 'has_spam_word(0)': False, 'has_spam_collocation(0)': False, 'contains(check)' ...

# %%
fset = [(document_attributes(text), labels) for text, labels in zip(dataframe['tokens'], dataframe['labels_num'].values)]
random.shuffle(fset)
print(len(fset))
# Out:
# 16347

# %%
train, test = fset[:13078], fset[13078:]

# %%
classifier = nltk.NaiveBayesClassifier.train(train)

# %%
print(nltk.classify.accuracy(classifier, test))
# Out:
# 0.9816457632303457

# %%
# Save Model
import pickle
f = open('email_spam_ham_classifier.pickle', 'wb')
pickle.dump(classifier, f)
f.close()

# %%
# Load model
import pickle
f = open('email_spam_ham_classifier.pickle', 'rb')
classifierLoaded = pickle.load(f)
f.close()

# %%
print(nltk.classify.accuracy(classifierLoaded, test))
# Out:
# 0.9816457632303457
