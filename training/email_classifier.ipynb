# %% [markdown]
# # Add libraries
# ---

# %%
import os
import nltk
import random
from nltk import word_tokenize
from nltk.collocations import *
import pandas as pd

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # Load corpus datasets
# ---

# %%
# !git clone https://github.com/pachocamacho1990/datasets
! unzip datasets/email/plaintext/corpus1.zip
! unzip datasets/email/plaintext/corpus2.zip
! unzip datasets/email/plaintext/corpus3.zip

# %%
# Get Text and labels from folders with plain text files
def get_text_labels_from_folders(folderBase, folderLabels):
  data = []
  labels = []

  for folderLabel in folderLabels:
    for file in os.listdir('{}/{}'.format(folderBase, folderLabel)):
      with open('{}/{}/{}'.format(folderBase, folderLabel, file), encoding='latin-1') as f:
        data.append(f.read())
        labels.append(folderLabel)

  return data, labels

# %%
def set_label_num(label_str):
  if label_str == "spam":
      return 1
  else:
      return 0

# %%
dataCorpus1, labelsCorpus1 = get_text_labels_from_folders('corpus1', ["spam", "ham"])
dataCorpus2, labelsCorpus2 = get_text_labels_from_folders('corpus2', ["spam", "ham"])
dataCorpus3, labelsCorpus3 = get_text_labels_from_folders('corpus3', ["spam", "ham"])

# %%
data = dataCorpus1 + dataCorpus2 + dataCorpus3
labels = labelsCorpus1 + labelsCorpus2 + labelsCorpus3

# %%
len(data)
# Out:
# 16347

# %%
dataframe = pd.DataFrame({'text': data, 'labels': labels})

# %%
dataframe = dataframe.sample(frac = 1)

# %%
dataframe['tokens'] = dataframe['text'].apply(lambda x: word_tokenize(x))

# %%
dataframe['labels_num'] = dataframe['labels'].apply(lambda x: set_label_num(x))

# %% [markdown]
# # Collocations
# ---

# %%
def filter_words_by_threshold(text_tokenized, threshold = 3, ):
  words = []
  words = [word for word in text_tokenized if len(word) > threshold]
  return words

# %%
def get_n_grams_collocations_from_words(words, freq_filter = 10, n_best= 10,
                                       n_gran_measure = nltk.collocations.BigramAssocMeasures()):
  finder = BigramCollocationFinder.from_words(words)
  finder.apply_freq_filter(freq_filter)
  email_spam_collocations = finder.nbest(n_gran_measure.pmi, n_best)
  return email_spam_collocations

# %%
spamCorpus1, _ = get_text_labels_from_folders('corpus1', ["spam"])
spamCorpus2, _ = get_text_labels_from_folders('corpus2', ["spam"])
spamCorpus3, _ = get_text_labels_from_folders('corpus3', ["spam"])
spamCorpuses = spamCorpus1 + spamCorpus2 + spamCorpus3

# %%
filtered_words = []
for text in spamCorpuses:
  filtered_words += filter_words_by_threshold(word_tokenize(text))
filtered_words

# %%
email_spam_collocations = get_n_grams_collocations_from_words(filtered_words, 120, 40)
email_spam_collocations

# %% [markdown]
# # Get document attributes
# ---

# %%
dataframe.head()
# Out:
#                                                     text  ... labels_num
# 4256   Subject: re : tglo status\ncost centers 11814 ...  ...          0
# 7988   Subject: sitescooper : scoop websites onto you...  ...          1
# 7254   Subject: you were accepted . here is your mone...  ...          1
# 15518  Subject: re : tw ios posting privileged & conf...  ...          0
# 14486  Subject: cheapest drug & s on the net . . . gu...  ...          1
#
# [5 rows x 4 columns]

# %%
def document_attributes(document):
  document_words = set(document)
  atrib = {}

  last_word = ""
  for word in document_words:
    atrib['contains({})'.format(word)] = (word in document_words)

    has_spam_word = False

    for bigram_position_0, bigram_position_1 in email_spam_collocations:
      if word == bigram_position_0 or word == bigram_position_1:
        has_spam_word = True
        break
    
    atrib['has_spam_word({})'.format(word)] = has_spam_word

    if (len(word) > 3):
      lastWord = word

  filtered_words = filter_words_by_threshold(document)
  bigrams = get_n_grams_collocations_from_words(filtered_words, n_best=10, freq_filter=5)

  for i in range(len(bigrams)):
    atrib['bigram_collocation({})'.format(i)] = bigrams[i]
    
  return atrib

# %%
dataframe.size
# Out:
# 65388

# %%
print(dataframe['tokens'].values[0])
print()
print("===="*100)
print()
print(document_attributes(dataframe['tokens'].values[0]))
# Out:
# ['Subject', ':', 're', ':', 'tglo', 'status', 'cost', 'centers', '11814', 'and', '27117', 'are', 'rolling', 'to', 'texas', 'gas', 'trading', '.', '-', '-', '-', '-', '-', 'original', 'message', '-', '-', '-', '-', '-', 'from', ':', 'coffey', 'jr', '.', ',', 'jim', 'sent', ':', 'tuesday', ',', 'october', '30', ',', '2001', '10', ':', '05', 'am', 'to', ':', 'parker', ',', 'megan', ';', 'boyt', ',', 'eric', ';', 'farmer', ',', 'daren', 'j', '.', 'cc', ':', 'bryan', ',', 'gary', ';', 'pond', ',', 'jim', ';', 'helton', ',', 'susan', ';', 'east', ',', 'laynie', ';', 'roberts', ',', 'linda', 'subject', ':', 're', ':', 'tglo', 'status', 'megan', 'as', 'i', 'mentioned', 'to', 'you', 'yesterday', ',', 'it', 'still', 'looks', 'like', 'the', 'volumes', 'for', 'gas', 'delivered', 'to', 'tx', 'glo', 'do', 'not', 'have', 'linda', 'robert', "'", 's', 'origination', 'fee', 'deducted', '.', 'do', 'we', 'need', 'to', 'execute', 'a', 'pma', 'with', 'txglo', 'to', 'deduct', 'those', 'volumes', 'from', 'the', 'next', 'delievery', '?', 'also', 'isn', "'", 't', 'there', 'an', 'entry', 'that', 'is', 'missing', 'in', 'your', 'file', 'to', 'capture', 'the', '$', 'cost', 'of', 'gas', 'for', 'the', 'gas', 'delivered', 'to', 'txglo', '?', 'is', 'that', 'being', 'captured', 'in', 'unify', 'or', 'is', 'it', 'being', 'manually', 'entered', 'by', 'gas', 'accounting', '?', 'darren', 'do', 'we', 'need', 'to', 'execute', 'a', 'seperate', 'deal', 'ticket', 'for', 'the', 'origination', 'deduct', '?', 'susan', '/', 'laynie', 'what', 'busines', 'unit', 'are', 'these', 'cost', 'centers', 'rolling', 'up', 'to', '(', '11814', 'coffey', 'jr', '.', ',', 'jim', 'subject', ':', 'tglo', 'status', 'eric', ':', 'i', 'reviewed', 'the', 'gas', 'deals', 'on', 'franks', "'", 'spreadsheet', 'and', 'they', 'agree', 'with', 'what', 'is', 'in', 'sitara', '.', 'as', 'soon', 'as', 'i', 'have', 'the', 'october', 'gas', 'numbers', ',', 'i', 'will', 'forward', 'them', 'to', 'you', '.', 'attached', 'is', 'a', 'spreadsheet', 'of', 'the', 'tglo', 'deals', 'booked', 'to', 'the', 'gl', 'to', 'help', 'you', 'with', 'our', 'current', 'settlement', 'position', '.', 'it', 'is', 'divided', 'by', 'debit', '/', 'credit', 'entries', '.', 'when', 'the', 'sales', 'are', 'booked', ',', 'a', 'debit', 'hits', 'the', 'customer', 'account', 'to', 'create', 'the', 'open', 'sale', 'to', 'apply', 'the', 'cash', 'to', 'and', 'a', 'credit', 'hits', 'the', 'revenue', 'account', '(', '40004000', 'third', 'party', ';', '40005000', 'intercompany', ')', 'for', 'the', 'profit', 'center', '.', 'below', 'is', 'a', 'summary', 'of', 'where', 'we', 'are', 'on', 'the', 'sale', 'dollars', 'to', 'egm', '.', 'i', 'have', 'already', 'sent', 'an', 'email', 'to', 'risk', 'to', 'update', 'the', 'demand', 'fees', 'for', 'the', 'prior', 'months', 'and', 'to', 'book', 'aug', 'and', 'sept', 'crude', '.', 'i', 'will', 'wait', 'for', 'the', 'go', 'ahead', 'from', 'frank', 'before', 'i', 'final', 'them', 'to', 'the', 'gl', '.', 'let', 'me', 'know', 'if', 'you', 'have', 'any', 'questions', '.', 'megan', 'status', 'of', 'sales', 'to', 'egm', 'cleared', 'invoices', '$', '3', ',', '905', ',', '963', '.', '20', 'open', 'invoices', '$', '1', ',', '177', ',', '587', '.', '60', 'to', 'be', 'booked', '$', '3', ',', '093', ',', '424', '.', '22', '$', '8', ',', '176', ',', '975', '.', '55', '>']
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================
#
# {'contains(current)': True, 'has_spam_word(current)': False, 'contains(linda)': True, 'has_spam_word(linda)': False, 'contains(trading)': True, 'has_spam_word(trading)': False, 'contains(,)': True, 'has_spam_word(,)': False, 'contains(dollars)': True, 'has_spam_word(dollars)': False, 'contains(txglo)': True, 'has_spam_word(txglo)': False, 'contains(east)': True, 'has_spam_word(east)': False, 'contains(email)': True, 'has_spam_word(email)': False, 'contains(pma)': True, 'has_spam_word(pma)': False, 'contains(your)': True, 'has_spam_word(your)': False, 'contains(it)': True, 'has_spam_word(it)': False, 'contains(below)': True, 'has_spam_word(below)': False, 'contains(divided)': True, 'has_spam_word(divided)': False, 'contains(parker)': True, 'has_spam_word(parker)': False, 'contains(a)': True, 'has_spam_word(a)': False, 'contains(position)': True, 'has_spam_word(position)': False, 'contains(sept)': True, 'has_spam_word(sept)': False, 'contains(cleared)': True, 'has_spam_word(cleared)': False, 'contains(22)': True, 'has_spam_word(22)': False, 'contains(10)': True, 'has_spam_word(10)': False, 'contains(laynie)': True, 'has_spam_word(laynie)': False, 'contains(final)': True, 'has_spam_word(final)': False, 'contains(also)': True, 'has_spam_word(also)': False, 'contains(and)': True, 'has_spam_word(and)': False, 'contains(to)': True, 'has_spam_word(to)': False, 'contains(from)': True, 'has_spam_word(from)': False, 'contains(frank)': True, 'has_spam_word(frank)': False, 'contains(jim)': True, 'has_spam_word(jim)': False, 'contains(subject)': True, 'has_spam_word(subject)': False, 'contains(what)': True, 'has_spam_word(what)': False, 'contains(know)': True, 'has_spam_word(know)': False, 'contains(by)': True, 'has_spam_word(by)': False, 'contains(customer)': True, 'has_spam_word(customer)': False, 'contains(cc)': True, 'has_spam_word(cc)': False, 'contains(on)': True, 'has_spam_word(on)': False, 'contains(soon)': True, 'has_spam_word(soon)': False, 'contains(or)': True, 'has_spam_word(or)': False, 'contains(create)': True, 'has_spam_word(create)': False, 'contains(invoices)': True, 'has_spam_word(invoices)': False, 'contains(20)': True, 'has_spam_word(20)': False, 'contains(update)': True, 'has_spam_word(update)': False, 'contains(have)': True, 'has_spam_word(have)': False, 'contains(cash)': True, 'has_spam_word(cash)': False, 'contains(glo)': True, 'has_spam_word(glo)': False, 'contains(boyt)': True, 'has_spam_word(boyt)': False, 'contains(unit)': True, 'has_spam_word(unit)': False, 'contains(status)': True, 'has_spam_word(status)': False, 'contains(coffey)': True, 'has_spam_word(coffey)': False, 'contains(agree)': True, 'has_spam_word(agree)': False, 'contains(months)': True, 'has_spam_word(months)': False, 'contains(help)': True, 'has_spam_word(help)': False, 'contains(2001)': True, 'has_spam_word(2001)': False, 'contains(aug)': True, 'has_spam_word(aug)': False, 'contains(gary)': True, 'has_spam_word(gary)': False, 'contains(/)': True, 'has_spam_word(/)': False, 'contains(manually)': True, 'has_spam_word(manually)': False, 'contains(seperate)': True, 'has_spam_word(seperate)': False, 'contains(deal)': True, 'has_spam_word(deal)': False, 'contains(sitara)': True, 'has_spam_word(sitara)': False, 'contains(spreadsheet)': True, 'has_spam_word(spreadsheet)': False, 'contains(()': True, 'has_spam_word(()': False, 'contains(yesterday)': True, 'has_spam_word(yesterday)': False, 'contains(s)': True, 'has_spam_word(s)': False, 'contains(account)': True, 'has_spam_word(account)': False, 'contains(accounting)': True, 'has_spam_word(accounting)': False, 'contains(let)': True, 'has_spam_word(let)': False, 'contains(30)': True, 'has_spam_word(30)': False, 'contains(as)': True, 'has_spam_word(as)': False, 'contains(05)': True, 'has_spam_word(05)': False, 'contains(deducted)': True, 'has_spam_word(deducted)': False, 'contains(where)': True, 'has_spam_word(where)': False, 'contains(centers)': True, 'has_spam_word(centers)': False, 'contains(60)': True, ...

# %%
fset = [(document_attributes(text), labels) for text, labels in zip(dataframe['tokens'], dataframe['labels_num'].values)]
random.shuffle(fset)
print(len(fset))
# Out:
# 16347

# %%
train, test = fset[:13078], fset[13078:]

# %%
classifier = nltk.NaiveBayesClassifier.train(train)

# %%
print(nltk.classify.accuracy(classifier, test))
# Out:
# 0.9798103395533803

# %%
# Save Model
import pickle
f = open('email_spam_ham_classifier.pickle', 'wb')
pickle.dump(classifier, f)
f.close()

# %%
# Load model
import pickle
f = open('email_spam_ham_classifier.pickle', 'rb')
classifierLoaded = pickle.load(f)
f.close()

# %%
print(nltk.classify.accuracy(classifierLoaded, test))
# Out:
# 0.9798103395533803
